# %% [markdown]
# # Integrantes
#
#
# -Azucena Reyes Garcia
#
# -Ricardo Hernandez Monroy
#
# -Daniel Lopez Gonzalez

# %% [markdown]
# # Problema 12
#
# Nutrición. El número de calorías correspondiente a los alimentos tipo sándwich que se sirven en un negocio de comida rápida se presenta a continuación:
#
# <table>
# <thead>
#
# </thead>
#
# <tbody>
# <tr>
# <td>250</td>
# <td>790</td>
# <td>470</td>
# <td>510</td>
# <td>500</td>
# <td>330</td>
# </tr>
# <tr>
# <td>300</td>
# <td>750</td>
# <td>580</td>
# <td>740</td>
# <td>420</td>
# <td>260</td>
# </tr>
# <tr>
# <td>440</td>
# <td>770</td>
# <td>400</td>
# <td>540</td>
# <td>530</td>
# <td>330</td>
# </tr>
# <tr>
# <td>390</td>
# <td>380</td>
# <td>340</td>
# <td>460</td>
# <td>530</td>
# <td>260</td>
# </tr>
# <tr>
# <td>410</td>
# <td>360</td>
# <td>270</td>
# <td>510</td>
# <td>630</td>
# <td>330</td>
# </tr>
#
# </tbody>
# </table>
#
#
#
# a. Realiza un histograma usando seis clases. Describe la forma de la distribución de los datos.
#
# b. Traza una ojiva y expón tus conclusiones.
#
# c. Forma un equipo de trabajo e investiga cuál es la ingesta calórica diaria de un mexicano.
#
# Compara ese resultado con los incisos anteriores. ¿Has pensado qué sucede si consumes alimentos con muchas calorías?

# %%
import matplotlib.pyplot as plt
print("Setup terminado")
# Out:
# Setup terminado

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Tabla de Clases</title>
#     <style>
#         table {
#             border-collapse: collapse;
#         }
#         th, td {
#             border: 1px solid black;
#             padding: 8px;
#         }
#     </style>
# </head>
# <body>
#     <table>
#         <thead>
#             <tr>
#                 <th>Clase</th>
#                 <th>Límite Inferior</th>
#                 <th>Límite Superior</th>
#                 <th>Valores</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Clase 1</td>
#                 <td>216.835</td>
#                 <td>304.168</td>
#                 <td>4</td>
#             </tr>
#             <tr>
#                 <td>Clase 2</td>
#                 <td>304.168</td>
#                 <td>391.501</td>
#                 <td>5</td>
#             </tr>
#             <tr>
#                 <td>Clase 3</td>
#                 <td>391.501</td>
#                 <td>478.834</td>
#                 <td>3</td>
#             </tr>
#             <tr>
#                 <td>Clase 4</td>
#                 <td>478.834</td>
#                 <td>566.167</td>
#                 <td>5</td>
#             </tr>
#             <tr>
#                 <td>Clase 5</td>
#                 <td>566.167</td>
#                 <td>653.501</td>
#                 <td>3</td>
#             </tr>
#             <tr>
#                 <td>Clase 6</td>
#                 <td>653.501</td>
#                 <td>740.834</td>
#                 <td>3</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %%
Marcas_clase = ['Clase 1', 'Clase 2', 'Clase 3', 'Clase 4', 'Clase 5', 'Clase 6']
frecuencia = [4, 5, 3, 5, 3, 3]

plt.figure(figsize=(12, 6))

# Histograma con:
# - Barras ajustadas al ancho de 1
# - Contorno negro (edgecolor = "k")
# - Colores para cada clase

plt.bar(Marcas_clase, frecuencia, width=1, edgecolor="k",
        color=["#E9FF33", "#8DFF33", "#33FFB2", "#33E0FF", "#FF3933", "#3933FF"])
plt.xlabel("Marca de clase", fontsize=25)
plt.ylabel("Frecuencia absoluta", fontsize=25)
plt.title("Histograma", fontsize=40)
plt.grid()
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Cuadro de Clases</title>
#     <style>
#         table {
#             border-collapse: collapse;
#         }
#         th, td {
#             border: 1px solid black;
#             padding: 8px;
#         }
#     </style>
# </head>
# <body>
#     <table>
#         <thead>
#             <tr>
#                 <th>Clase</th>
#                 <th>Acumulación de Valores</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Clase 1</td>
#                 <td>4</td>
#             </tr>
#             <tr>
#                 <td>Clase 2</td>
#                 <td>9</td>
#             </tr>
#             <tr>
#                 <td>Clase 3</td>
#                 <td>12</td>
#             </tr>
#             <tr>
#                 <td>Clase 4</td>
#                 <td>17</td>
#             </tr>
#             <tr>
#                 <td>Clase 5</td>
#                 <td>20</td>
#             </tr>
#             <tr>
#                 <td>Clase 6</td>
#                 <td>23</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %%
plt.figure(figsize=(12, 6))  # (Ancho, largo) del gráfico
marcas_clase = ["Clase 1", "Clase 2", "Clase 3", "Clase 4", "Clase 5", "Clase 6"]
frecuencia = [4, 9, 12, 17, 20, 23]

# Ajuste a las listas para generar el polígono de frecuencias
datos_x = [0] + marcas_clase
datos_y = [0] + frecuencia

# Polígono de frecuencias con:
# - Estilo de líneas punteado (linestyle=":"). Consulta la documentación para obtener más estilos de líneas.
# - Marcador con forma circular (marker="v"). Consulta la documentación para obtener más marcadores.
plt.plot(datos_x, datos_y,
         linewidth=4, color="g", linestyle=":",
         marker="*", markersize=20, markeredgecolor="k", markerfacecolor="y")

plt.xticks(marcas_clase, fontsize=15, rotation=45)
plt.xlabel("Marcas de clase", fontsize=25)
plt.ylabel("Frecuencia acumulada", fontsize=25)
plt.title("Ojiva", fontsize=40)
plt.grid(True)
plt.show()
